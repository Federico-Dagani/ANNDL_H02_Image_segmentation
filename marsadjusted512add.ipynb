# %% [markdown]
# ## ⚙️ Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

from datetime import datetime

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt

import seaborn as sns
import pandas as pd

import hashlib
from collections import defaultdict
import matplotlib.pyplot as plt

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.16.1

# %% [markdown]
# ## ⏳ Load

# %%
# Load the dataset
print("Loading Mars dataset...")
data = np.load("/kaggle/input/mars-training-set/mars_for_students.npz")
training_set = data["training_set"]
X_train = training_set[:, 0]
y_train = training_set[:, 1]
X_test = data["test_set"]

# Add a channel
X_train_val = X_train[..., np.newaxis]
y_train_val = y_train[..., np.newaxis]
X_test = X_test[..., np.newaxis] 
X_test = X_test / 255.0

print("Dataset loaded!")

input_shape = X_train.shape[1:]
num_classes = len(np.unique(y_train_val))

print(f"\nInput shape: {input_shape}")
print(f"Number of classes: {num_classes}")

print(f"\nShape of X_train: {X_train_val.shape}")
print(f"Shape of y_train: {y_train_val.shape}")
print(f"Shape of X_test: {X_test.shape}")
# Out:
# Loading Mars dataset...
# Dataset loaded!
#
# Input shape: (64, 128)
# Number of classes: 5
#
# Shape of X_train: (2615, 64, 128, 1)
# Shape of y_train: (2615, 64, 128, 1)
# Shape of X_test: (10022, 64, 128, 1)

# %% [markdown]
# ## 👽 Detect Outliers

# %%
# Function to calculate the hash of an image
def calculate_image_hash(image):
    return hashlib.md5(image.tobytes()).hexdigest()

# Calculate hashes for each image and store their indices
hash_dict = defaultdict(list)
for idx, image in enumerate(y_train_val):
    img_hash = calculate_image_hash(image)
    hash_dict[img_hash].append(idx)

# %%
# Find duplicates
duplicates = {key: indices for key, indices in hash_dict.items() if len(indices) > 1}

if duplicates:
    print("Duplicate images found!")
   
    num_duplicates = len(duplicates)
    cols = 5 
    rows = (num_duplicates + cols - 1) // cols  
    
    # Create the figure and subplots
    fig, axes = plt.subplots(rows, cols, figsize=(15, 3 * rows))
    axes = axes.flatten()  
    
    for i, (img_hash, indices) in enumerate(duplicates.items()):
        # Select one representative image
        representative_idx = indices[0]
        occurrence_count = len(indices)  
        ax = axes[i]
        
        # Plot the image
        if y_train_val[representative_idx].ndim == 3: 
            ax.imshow(y_train_val[representative_idx])
        else: 
            ax.imshow(y_train_val[representative_idx], cmap='gray')
        
        # Set title with hash, occurrences, and first index
        ax.set_title(f"Idx: {representative_idx}, Count: {occurrence_count}")
        ax.axis('off')
    
    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout()
    plt.show()

else:
    print("No duplicate images found!")
# Out:
# Duplicate images found!

# %% [markdown]
# ## Inspect an index

# %%
def create_segmentation_colormap(num_classes):
    return plt.cm.viridis(np.linspace(0, 1, num_classes))

# %%
def apply_colormap(label, colormap=None):
    
    # Ensure label is 2D
    label = np.squeeze(label)

    # Ensure label values are in the valid range [0, num_classes-1]
    num_classes = len(colormap)  # Get the number of classes from the colormap
    label = np.clip(label, 0, num_classes - 1)  # Clip values to be within range

    # Apply the colormap
    colored = colormap[label.astype(int)]

    return colored

# %%
index_of_interest = 2071

# Function to get images associated with a specific index
def get_images_by_index(index):
    img_hash = calculate_image_hash(y_train_val[index])  # Calculate hash
    associated_indices = hash_dict.get(img_hash, [])  # Get duplicate indices
    return img_hash, associated_indices

# Get images and duplicates
img_hash, associated_indices = get_images_by_index(index_of_interest)

if associated_indices:
    print(f"Hash for image at index {index_of_interest}: {img_hash}")
    
    num_images = len(associated_indices)
    cols = 2  # Show image and label side-by-side
    rows = num_images  # One row per image-label pair
    
    # Create colormap for labels
    num_classes = len(np.unique(y_train_val))
    colormap = create_segmentation_colormap(num_classes)

    # Larger figure size for better visuals
    fig, axes = plt.subplots(rows, cols, figsize=(20, 10 * rows))
    axes = axes.reshape(rows, cols)  # Ensure axes is 2D for easy access

    for i, idx in enumerate(associated_indices):
        # Plot the image
        ax_image = axes[i, 0]
        ax_image.imshow(X_train_val[idx], cmap='gray' if X_train_val[idx].ndim == 2 else None)
        ax_image.set_title(f"Image Idx: {idx}")
        ax_image.axis('off')

        # Plot the label
        ax_label = axes[i, 1]
        colored_label = apply_colormap(y_train_val[idx], colormap)
        ax_label.imshow(colored_label)
        ax_label.set_title("Label")
        ax_label.axis('off')

    plt.subplots_adjust(wspace=0.4, hspace=0.4)  # Adjust spacing
    plt.tight_layout()
    plt.show()

else:
    print(f"No duplicates found for image at index {index_of_interest}.")
# Out:
# Hash for image at index 2071: 17fec901f6ed4082a70668bf7a334b37

# %%
alien_index = 62

# Get associated indices
img_hash, alin_associated_indices = get_images_by_index(alien_index)

if(X_train_val.shape[0] == 2615):
    X_train_val = np.delete(X_train_val, alin_associated_indices, axis=0)
    y_train_val = np.delete(y_train_val, alin_associated_indices, axis=0)
    print("Outliers removed")
else:
    print("Outliers already removed")

print("Dataset dimension:", X_train_val.shape)
# Out:
# Outliers removed
# Dataset dimension: (2505, 64, 128, 1)

# %% [markdown]
# ## Adjust labels

# %%
hash_dict = defaultdict(list)
for idx, image in enumerate(y_train_val):
    img_hash = calculate_image_hash(image)
    hash_dict[img_hash].append(idx)

# %%
# Find duplicates
duplicates = {key: indices for key, indices in hash_dict.items() if len(indices) > 1}

if duplicates:
    print("Duplicate images found!")
   
    num_duplicates = len(duplicates)
    cols = 5 
    rows = (num_duplicates + cols - 1) // cols  
    
    # Create the figure and subplots
    fig, axes = plt.subplots(rows, cols, figsize=(15, 3 * rows))
    axes = axes.flatten()  
    
    for i, (img_hash, indices) in enumerate(duplicates.items()):
        # Select one representative image
        representative_idx = indices[0]
        occurrence_count = len(indices)  
        ax = axes[i]
        
        # Plot the image
        if y_train_val[representative_idx].ndim == 3: 
            ax.imshow(y_train_val[representative_idx])
        else: 
            ax.imshow(y_train_val[representative_idx], cmap='gray')
        
        # Set title with hash, occurrences, and first index
        ax.set_title(f"Idx: {representative_idx}, Count: {occurrence_count}")
        ax.axis('off')
    
    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout()
    plt.show()

else:
    print("No duplicate images found!")
# Out:
# Duplicate images found!

# %%
index_of_interest = 55

# Function to get images associated with a specific index
def get_images_by_index(index):
    img_hash = calculate_image_hash(y_train_val[index])  # Calculate hash
    associated_indices = hash_dict.get(img_hash, [])  # Get duplicate indices
    return img_hash, associated_indices

# Get images and duplicates
img_hash, associated_indices = get_images_by_index(index_of_interest)

if associated_indices:
    print(f"Hash for image at index {index_of_interest}: {img_hash}")
    
    num_images = len(associated_indices)
    cols = 2  # Show image and label side-by-side
    rows = num_images  # One row per image-label pair
    
    # Create colormap for labels
    num_classes = len(np.unique(y_train_val))
    colormap = create_segmentation_colormap(num_classes)

    # Larger figure size for better visuals
    fig, axes = plt.subplots(rows, cols, figsize=(20, 10 * rows))
    axes = axes.reshape(rows, cols)  # Ensure axes is 2D for easy access

    for i, idx in enumerate(associated_indices):
        # Plot the image
        ax_image = axes[i, 0]
        ax_image.imshow(X_train_val[idx], cmap='gray' if X_train_val[idx].ndim == 2 else None)
        ax_image.set_title(f"Image Idx: {idx}")
        ax_image.axis('off')

        # Plot the label
        ax_label = axes[i, 1]
        colored_label = apply_colormap(y_train_val[idx], colormap)
        ax_label.imshow(colored_label)
        ax_label.set_title("Label")
        ax_label.axis('off')

    plt.subplots_adjust(wspace=0.4, hspace=0.4)  # Adjust spacing
    plt.tight_layout()
    plt.show()

else:
    print(f"No duplicates found for image at index {index_of_interest}.")
# Out:
# Hash for image at index 55: b740b976f8159c12b8e98d4c23e4b4a7

# %%
# Step 1: Iterate through each element in the duplicates dictionary
for key, indices in duplicates.items():

    # Step 2: For each image in the current group (indices), get the corresponding labels
    labels_to_adjust = [y_train_val[idx] for idx in indices]
    
    # Step 3: Find the most frequent label in each of the labels
    unique_values, counts = np.unique(labels_to_adjust[0], return_counts=True)
    most_frequent_label = unique_values[np.argmax(counts)]
    
    for label in labels_to_adjust:
        # Step 4: Adjust the label - replace the other values with the most frequent label
        adjusted_label = np.where(label != most_frequent_label, most_frequent_label, label)
        
    # Step 5: Replace the original label with the adjusted label
    for idx in indices:
        y_train_val[idx] = adjusted_label

# %%
# Example list of indexes you want to display
indexes_to_display = [55]  # Replace with your specific indexes

# Number of images to display
num_images = len(indexes_to_display)

# Create a larger figure to accommodate multiple images and labels
fig, axes = plt.subplots(num_images, 2, figsize=(10, 5 * num_images))

# Loop through the selected indexes
for i, idx in enumerate(indexes_to_display):
    # Image plot
    ax_image = axes[i, 0] if num_images > 1 else axes[0]
    ax_image.imshow(X_train_val[idx], cmap='gray' if X_train_val[idx].ndim == 2 else None)  # Grayscale if 2D
    ax_image.set_title(f"Image Index: {idx}")
    ax_image.axis('off')

    # Label plot
    ax_label = axes[i, 1] if num_images > 1 else axes[1]
    colored_label = apply_colormap(y_train_val[idx], colormap)
    ax_label.imshow(colored_label)
    ax_label.set_title(f"Label for Index: {idx}")
    ax_label.axis('off')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔄 Process Data

# %%
# Set batch size for training
BATCH_SIZE = 64

# Set learning rate for the optimiser
#LEARNING_RATE = 1e-3

# Set early stopping patience threshold
PATIENCE = 30

# Set maximum number of training epochs
EPOCHS = 1000

# Set data split size for training and validation
SPLITS_SIZE = 0.2

# %%
# Split the training set into training and validation sets
print("Splitting data...")
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=SPLITS_SIZE, random_state=seed
)
print("Data splitted!")

# Display dataset information
print(f"\nNumber of images:")
print(f"Training set: {len(X_train)}")
print(f"Validation set: {len(X_val)}")
print(f"Test set: {len(X_test)}")
# Out:
# Splitting data...
# Data splitted!
#
# Number of images:
# Training set: 2004
# Validation set: 501
# Test set: 10022

# %%
# Define the category mapping
category_map = {
        0: 0,  # background
        1: 1,  # soil
        2: 2,  # bedrock
        3: 3,  # sand
        4: 4   # big rock
}

# Define the classes 
classes = ['background', 'soil', 'bedrock', 'sand', 'big rock'] 

NUM_CLASSES = len(set(category_map.values()))
print(f"Number of categories: {len(category_map)}")
# Out:
# Number of categories: 5

# %%
def preprocess_data(X, y, input_size=(64, 128)):
    X = tf.image.resize(X, input_size)
    X = tf.cast(X, tf.float32) / 255.0
    
    y = tf.image.resize(y, input_size, method='bilinear')
    y = tf.cast(y, tf.int32)
    return X, y

# %%
def apply_category_mapping(label):
    """
    Apply category mapping to labels.
    """
    keys_tensor = tf.constant(list(category_map.keys()), dtype=tf.int32)
    vals_tensor = tf.constant(list(category_map.values()), dtype=tf.int32)
    table = tf.lookup.StaticHashTable(
        tf.lookup.KeyValueTensorInitializer(keys_tensor, vals_tensor),
        default_value=0
    )
    return table.lookup(label)

# %%
# Define augmentation
@tf.function
def random_flip(image, label, seed=None):
    """Consistent random horizontal flip."""
    if seed is None:
        seed = np.random.randint(0, 1000000)
    flip_prob = tf.random.uniform([], seed=seed)
    image = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_left_right(image),
        lambda: image
    )
    label = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_left_right(label),
        lambda: label
    )
    return image, label

# %%
def make_dataset(X, y, batch_size, shuffle=True, augment=False, seed=None):
    """
    Create a TensorFlow dataset. 
    """
    # Create dataset from file paths
    dataset = tf.data.Dataset.from_tensor_slices((X, y)) #create data from images and masks

    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed) #we can shuffle it

    # Preprocess immages and labels
    dataset = dataset.map(
        preprocess_data,
        num_parallel_calls=tf.data.AUTOTUNE
    )
    
    # Apply category mapping: change the labels
    dataset = dataset.map(
        lambda x, y: (x, apply_category_mapping(y)),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    if augment: #apply random flip
        dataset = dataset.map(
            lambda x, y: random_flip(x, y, seed=seed),
            num_parallel_calls=tf.data.AUTOTUNE
        )

    # Batch the data (do it now and not at training time)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
# Create the datasets
print("Creating datasets...")
train_dataset = make_dataset(
    X_train, y_train, 
    batch_size=BATCH_SIZE,
    shuffle=True,
    augment=True,
    seed=seed
)

val_dataset = make_dataset(
    X_val, y_val,
    batch_size=BATCH_SIZE,
    shuffle=False #for validation not necessary to shuffle it
)
print("Datasets created!")

# Check the shape of the data
for images, labels in train_dataset.take(1):
    input_shape = images.shape[1:]
    print(f"\nInput shape: {input_shape}")
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)
    print("Labels dtype:", labels.dtype)
    break
# Out:
# Creating datasets...
# Datasets created!
#
# Input shape: (64, 128, 1)
# Images shape: (64, 64, 128, 1)
# Labels shape: (64, 64, 128, 1)
# Labels dtype: <dtype: 'int32'>

# %%
# Plot real image and ground truth (reduced resolution)
def plot_sample_batch(dataset, num_samples=3):
    """
    Display some image and label pairs from the dataset.
    """
    plt.figure(figsize=(15, 4 * num_samples))

    for images, labels in dataset.take(1):
        labels_np = labels.numpy()
        num_classes = len(category_map)  # Ensure colormap covers all classes, including the background
        colormap = create_segmentation_colormap(num_classes)

        for j in range(min(num_samples, len(images))):
            # Plot original grayscale image (no colormap)
            plt.subplot(num_samples, 2, j * 2 + 1)
            plt.imshow(images[j], cmap='gray')  # Use 'gray' cmap for the images (ensure grayscale)
            plt.title(f'Image {j + 1}')
            plt.axis('off')

            # Plot colored label (apply colormap only to labels)
            plt.subplot(num_samples, 2, j * 2 + 2)
            colored_label = apply_colormap(labels_np[j], colormap)  # Apply colormap to the labels only
            plt.imshow(colored_label)  # Show the colored label
            plt.title(f'Label {j + 1}')
            plt.axis('off')

    plt.tight_layout()
    plt.show()
    plt.close()

    handles = []
    # After all images have been plotted, add the legend once
    for label_idx in category_map:
        color = colormap[label_idx]  # Use array indexing, subtracting 1 to account for class 0 exclusion
        handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=classes[label_idx]))
    
    # Create a single legend displayed at the bottom
    fig, ax = plt.subplots(figsize=(10, 2))  # Make the figure wide enough for a horizontal legend
    ax.legend(handles=handles, loc='center', bbox_to_anchor=(0.5, 0), title="Classes", ncol=len(category_map))
    ax.axis('off')
    plt.show()

# Visualize examples from the training set
print("Visualizing examples from the training set:")
plot_sample_batch(train_dataset, num_samples=8)
# Out:
# Visualizing examples from the training set:

# %% [markdown]
# ## 🛠️ Model Definition and Training

# %%
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # Return the transformed tensor
    return x

# %%
# Use transpose convolution instead of upsampling
def get_unet_model(input_shape=(64, 128, 1), num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')  # first block with 32 filters
    d1 = tfkl.MaxPooling2D()(down_block_1)  # reduce spatial complexity

    down_block_2 = unet_block(d1, 64, name='down_block2_')  # second block with 64 filters
    d2 = tfkl.MaxPooling2D()(down_block_2)

    down_block_3 = unet_block(d2, 128, name='down_block3_')  # third block with 128 filters
    d3 = tfkl.MaxPooling2D()(down_block_3)

    down_block_4 = unet_block(d3, 256, name='down_block4_')  # added block with 256 filters
    d4 = tfkl.MaxPooling2D()(down_block_4)

    # Bottleneck with 512 filters
    bottleneck = unet_block(d4, 512, name='bottleneck')  # bottleneck with 512 filters

    # Upsampling path: increase spatial complexity using transpose convolution
    u1 = tfkl.Conv2DTranspose(256, kernel_size=2, strides=2, padding='same')(bottleneck)  # Transpose Convolution
    u1 = tfkl.Add()([u1, down_block_4])  # Skip connection from downsampling path
    u1 = unet_block(u1, 256, name='up_block1_')  # first upsampling block with 256 filters

    u2 = tfkl.Conv2DTranspose(128, kernel_size=2, strides=2, padding='same')(u1)  # Transpose Convolution
    u2 = tfkl.Add()([u2, down_block_3])
    u2 = unet_block(u2, 128, name='up_block2_')  # second upsampling block with 128 filters

    u3 = tfkl.Conv2DTranspose(64, kernel_size=2, strides=2, padding='same')(u2)  # Transpose Convolution
    u3 = tfkl.Add()([u3, down_block_2])
    u3 = unet_block(u3, 64, name='up_block3_')  # third upsampling block with 64 filters

    u4 = tfkl.Conv2DTranspose(32, kernel_size=2, strides=2, padding='same')(u3)  # Transpose Convolution
    u4 = tfkl.Add()([u4, down_block_1])
    u4 = unet_block(u4, 32, name='up_block4_')  # fourth upsampling block with 32 filters

    # Output Layer: final convolution with softmax activation for segmentation
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u4)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet')
    return model

# %%
model = get_unet_model()

# Print a detailed summary of the model with expanded nested layers and trainable parameters.
model.summary(expand_nested=False, show_trainable=True)

# Generate and display a graphical representation of the model architecture.
tf.keras.utils.plot_model(model, show_trainable=True, expand_nested=False, dpi=70)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer       │ (None, 64, 128, │         0 │ -              │   -   │
# │ (InputLayer)      │ 1)              │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_conv1 │ (None, 64, 128, │       320 │ input_layer[0… │   Y   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_bn1   │ (None, 64, 128, │       128 │ down_block1_c… │   Y   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_acti… │ (None, 64, 128, │         0 │ down_block1_b… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_conv2 │ (None, 64, 128, │     9,248 │ down_block1_a… │   Y   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_bn2   │ (None, 64, 128, │       128 │ down_block1_c… │   Y   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block1_acti… │ (None, 64, 128, │         0 │ down_block1_b… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_19  │ (None, 32, 64,  │         0 │ down_block1_a… │   -   │
# │ (MaxPooling2D)    │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_conv1 │ (None, 32, 64,  │    18,496 │ max_pooling2d… │   Y   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_bn1   │ (None, 32, 64,  │       256 │ down_block2_c… │   Y   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_acti… │ (None, 32, 64,  │         0 │ down_block2_b… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_conv2 │ (None, 32, 64,  │    36,928 │ down_block2_a… │   Y   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_bn2   │ (None, 32, 64,  │       256 │ down_block2_c… │   Y   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block2_acti… │ (None, 32, 64,  │         0 │ down_block2_b… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_20  │ (None, 16, 32,  │         0 │ down_block2_a… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_conv1 │ (None, 16, 32,  │    73,856 │ max_pooling2d… │   Y   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_bn1   │ (None, 16, 32,  │       512 │ down_block3_c… │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_acti… │ (None, 16, 32,  │         0 │ down_block3_b… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_conv2 │ (None, 16, 32,  │   147,584 │ down_block3_a… │   Y   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_bn2   │ (None, 16, 32,  │       512 │ down_block3_c… │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block3_acti… │ (None, 16, 32,  │         0 │ down_block3_b… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_21  │ (None, 8, 16,   │         0 │ down_block3_a… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_conv1 │ (None, 8, 16,   │   295,168 │ max_pooling2d… │   Y   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_bn1   │ (None, 8, 16,   │     1,024 │ down_block4_c… │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_acti… │ (None, 8, 16,   │         0 │ down_block4_b… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_conv2 │ (None, 8, 16,   │   590,080 │ down_block4_a… │   Y   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_bn2   │ (None, 8, 16,   │     1,024 │ down_block4_c… │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ down_block4_acti… │ (None, 8, 16,   │         0 │ down_block4_b… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_22  │ (None, 4, 8,    │         0 │ down_block4_a… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckconv1   │ (None, 4, 8,    │ 1,180,160 │ max_pooling2d… │   Y   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckbn1     │ (None, 4, 8,    │     2,048 │ bottleneckcon… │   Y   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckactiva… │ (None, 4, 8,    │         0 │ bottleneckbn1… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckconv2   │ (None, 4, 8,    │ 2,359,808 │ bottleneckact… │   Y   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckbn2     │ (None, 4, 8,    │     2,048 │ bottleneckcon… │   Y   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bottleneckactiva… │ (None, 4, 8,    │         0 │ bottleneckbn2… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_transpose… │ (None, 8, 16,   │   524,544 │ bottleneckact… │   Y   │
# │ (Conv2DTranspose) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 8, 16,   │         0 │ conv2d_transp… │   -   │
# │                   │ 256)            │           │ down_block4_a… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_conv1   │ (None, 8, 16,   │   590,080 │ add_1[0][0]    │   Y   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_bn1     │ (None, 8, 16,   │     1,024 │ up_block1_con… │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_activa… │ (None, 8, 16,   │         0 │ up_block1_bn1… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_conv2   │ (None, 8, 16,   │   590,080 │ up_block1_act… │   Y   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_bn2     │ (None, 8, 16,   │     1,024 │ up_block1_con… │   Y   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block1_activa… │ (None, 8, 16,   │         0 │ up_block1_bn2… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_transpose… │ (None, 16, 32,  │   131,200 │ up_block1_act… │   Y   │
# │ (Conv2DTranspose) │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 16, 32,  │         0 │ conv2d_transp… │   -   │
# │                   │ 128)            │           │ down_block3_a… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_conv1   │ (None, 16, 32,  │   147,584 │ add_2[0][0]    │   Y   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_bn1     │ (None, 16, 32,  │       512 │ up_block2_con… │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_activa… │ (None, 16, 32,  │         0 │ up_block2_bn1… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_conv2   │ (None, 16, 32,  │   147,584 │ up_block2_act… │   Y   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_bn2     │ (None, 16, 32,  │       512 │ up_block2_con… │   Y   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block2_activa… │ (None, 16, 32,  │         0 │ up_block2_bn2… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_transpose… │ (None, 32, 64,  │    32,832 │ up_block2_act… │   Y   │
# │ (Conv2DTranspose) │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 32, 64,  │         0 │ conv2d_transp… │   -   │
# │                   │ 64)             │           │ down_block2_a… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_conv1   │ (None, 32, 64,  │    36,928 │ add_3[0][0]    │   Y   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_bn1     │ (None, 32, 64,  │       256 │ up_block3_con… │   Y   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_activa… │ (None, 32, 64,  │         0 │ up_block3_bn1… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_conv2   │ (None, 32, 64,  │    36,928 │ up_block3_act… │   Y   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_bn2     │ (None, 32, 64,  │       256 │ up_block3_con… │   Y   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block3_activa… │ (None, 32, 64,  │         0 │ up_block3_bn2… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_transpose… │ (None, 64, 128, │     8,224 │ up_block3_act… │   Y   │
# │ (Conv2DTranspose) │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 64, 128, │         0 │ conv2d_transp… │   -   │
# │                   │ 32)             │           │ down_block1_a… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_conv1   │ (None, 64, 128, │     9,248 │ add_4[0][0]    │   Y   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_bn1     │ (None, 64, 128, │       128 │ up_block4_con… │   Y   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_activa… │ (None, 64, 128, │         0 │ up_block4_bn1… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_conv2   │ (None, 64, 128, │     9,248 │ up_block4_act… │   Y   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_bn2     │ (None, 64, 128, │       128 │ up_block4_con… │   Y   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ up_block4_activa… │ (None, 64, 128, │         0 │ up_block4_bn2… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ output_layer      │ (None, 64, 128, │       165 │ up_block4_act… │   Y   │
# │ (Conv2D)          │ 5)              │           │                │       │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 6,988,069 (26.66 MB)
#  Trainable params: 6,982,181 (26.63 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
class MeanIntersectionOverUnion(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, labels_to_exclude=None, name="mean_iou", dtype=None):
        super(MeanIntersectionOverUnion, self).__init__(num_classes=num_classes, name=name, dtype=dtype)
        if labels_to_exclude is None:
            labels_to_exclude = [0]  # Default to excluding label 0
        self.labels_to_exclude = labels_to_exclude

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert predictions to class labels
        y_pred = tf.math.argmax(y_pred, axis=-1)

        # Flatten the tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])

        # Apply mask to exclude specified labels
        for label in self.labels_to_exclude:
            mask = tf.not_equal(y_true, label)
            y_true = tf.boolean_mask(y_true, mask)
            y_pred = tf.boolean_mask(y_pred, mask)

        # Update the state
        return super().update_state(y_true, y_pred, sample_weight)

# Visualization callback: plot during the training the prediction and the images
#useful for debugging ex. I'm stuck in a local minima where the less represented class is never predicted
class VizCallback(tf.keras.callbacks.Callback):
    def __init__(self, image, label, frequency=5):
        super().__init__()
        self.image_tensor = image  # The image tensor
        self.label_tensor = label  # The label tensor
        self.frequency = frequency

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.frequency == 0:  # Visualize only every "frequency" epochs
            image = self.image_tensor
            label = self.label_tensor
            image = tf.expand_dims(image, 0)
            pred = self.model.predict(image, verbose=0)        
            y_pred = tf.math.argmax(pred, axis=-1)
            y_pred = y_pred.numpy()

            # Create colormap
            num_classes = NUM_CLASSES
            colormap = create_segmentation_colormap(num_classes)

            plt.figure(figsize=(16, 4))

            # Input image
            plt.subplot(1, 3, 1)
            plt.imshow(image[0])
            plt.title("Input Image")
            plt.axis('off')

            # Ground truth
            plt.subplot(1, 3, 2)
            colored_label = apply_colormap(label.numpy(), colormap)
            plt.imshow(colored_label)
            plt.title("Ground Truth Mask")
            plt.axis('off')

            # Prediction
            plt.subplot(1, 3, 3)
            colored_pred = apply_colormap(y_pred[0], colormap)
            plt.imshow(colored_pred)
            plt.title("Predicted Mask")
            plt.axis('off')

            plt.tight_layout()
            plt.show()
            plt.close()

# %%
# Compile the model
print("Compiling model...")
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), #not categorical crossentropy
    optimizer=tf.keras.optimizers.AdamW(),
    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]
)
print("Model compiled!")
# Out:
# Compiling model...
# Model compiled!

# %%
# Setup callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

learning_rate = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.1, 
    patience=15, 
    min_delta=1e-5
)

first_element = next(iter(val_dataset.take(1)))
image, label = first_element
#viz_callback = VizCallback(image, label) #plot just the first image of validation set

# %%
# Train the model
history = model.fit( #batch size already defined in definition of data loader
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[early_stopping, learning_rate],
    verbose=1
).history

# Calculate and print the final validation accuracy
final_val_meanIoU = round(max(history['val_mean_iou'])* 100, 2)
print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')

# Save the trained model to a file 
timestep_str = datetime.now().strftime("%y%m%d_%H%M%S")
model_filename = f"model_{timestep_str}.keras"
model.save(model_filename)

print(f"Model saved to {model_filename}")

del model
# Out:
# Epoch 1/1000
# W0000 00:00:1733136874.757473      83 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.3532 - loss: 1.5173 - mean_iou: 0.1596
# W0000 00:00:1733136887.647154      82 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.3554 - loss: 1.5123 - mean_iou: 0.1607
# W0000 00:00:1733136899.398761      80 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1733136905.152651      83 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 822ms/step - accuracy: 0.3575 - loss: 1.5076 - mean_iou: 0.1617 - val_accuracy: 0.2360 - val_loss: 7.7100 - val_mean_iou: 0.0288 - learning_rate: 0.0010
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.4995 - loss: 1.1992 - mean_iou: 0.2269 - val_accuracy: 0.1982 - val_loss: 3.2302 - val_mean_iou: 0.0526 - learning_rate: 0.0010
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.5766 - loss: 1.0555 - mean_iou: 0.2873 - val_accuracy: 0.2212 - val_loss: 20.9085 - val_mean_iou: 8.0283e-04 - learning_rate: 0.0010
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.6037 - loss: 1.0006 - mean_iou: 0.3126 - val_accuracy: 0.1988 - val_loss: 3.0639 - val_mean_iou: 0.0662 - learning_rate: 0.0010
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.6292 - loss: 0.9387 - mean_iou: 0.3375 - val_accuracy: 0.2347 - val_loss: 2.6245 - val_mean_iou: 0.1093 - learning_rate: 0.0010
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - accuracy: 0.6193 - loss: 0.9637 - mean_iou: 0.3264 - val_accuracy: 0.2378 - val_loss: 4.4307 - val_mean_iou: 0.0127 - learning_rate: 0.0010
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - accuracy: 0.6497 - loss: 0.9027 - mean_iou: 0.3516 - val_accuracy: 0.1995 - val_loss: 3.7763 - val_mean_iou: 0.0524 - learning_rate: 0.0010
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.6478 - loss: 0.9050 - mean_iou: 0.3591 - val_accuracy: 0.2174 - val_loss: 5.0082 - val_mean_iou: 0.0445 - learning_rate: 0.0010
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.6616 - loss: 0.8654 - mean_iou: 0.3711 - val_accuracy: 0.1982 - val_loss: 5.6261 - val_mean_iou: 0.0656 - learning_rate: 0.0010
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.6871 - loss: 0.8261 - mean_iou: 0.3958 - val_accuracy: 0.2067 - val_loss: 4.7446 - val_mean_iou: 0.0480 - learning_rate: 0.0010
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6811 - loss: 0.8338 - mean_iou: 0.3837 - val_accuracy: 0.1984 - val_loss: 5.1319 - val_mean_iou: 0.0525 - learning_rate: 0.0010
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7027 - loss: 0.7812 - mean_iou: 0.4138 - val_accuracy: 0.1996 - val_loss: 4.2470 - val_mean_iou: 0.0525 - learning_rate: 0.0010
# Epoch 13/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7054 - loss: 0.7777 - mean_iou: 0.4068 - val_accuracy: 0.2042 - val_loss: 4.0856 - val_mean_iou: 0.0536 - learning_rate: 0.0010
# Epoch 14/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6994 - loss: 0.7791 - mean_iou: 0.4051 - val_accuracy: 0.2216 - val_loss: 3.5960 - val_mean_iou: 0.0584 - learning_rate: 0.0010
# Epoch 15/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.6936 - loss: 0.7826 - mean_iou: 0.4071 - val_accuracy: 0.2554 - val_loss: 3.7868 - val_mean_iou: 0.0774 - learning_rate: 0.0010
# Epoch 16/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7080 - loss: 0.7579 - mean_iou: 0.4132 - val_accuracy: 0.3056 - val_loss: 2.7022 - val_mean_iou: 0.1042 - learning_rate: 0.0010
# Epoch 17/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7228 - loss: 0.7294 - mean_iou: 0.4297 - val_accuracy: 0.3408 - val_loss: 2.9101 - val_mean_iou: 0.0961 - learning_rate: 0.0010
# Epoch 18/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7457 - loss: 0.6828 - mean_iou: 0.4525 - val_accuracy: 0.2842 - val_loss: 3.0589 - val_mean_iou: 0.0473 - learning_rate: 0.0010
# Epoch 19/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7034 - loss: 0.7652 - mean_iou: 0.4076 - val_accuracy: 0.4645 - val_loss: 2.3297 - val_mean_iou: 0.1774 - learning_rate: 0.0010
# Epoch 20/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7382 - loss: 0.7090 - mean_iou: 0.4431 - val_accuracy: 0.3936 - val_loss: 2.4613 - val_mean_iou: 0.1380 - learning_rate: 0.0010
# Epoch 21/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7482 - loss: 0.6694 - mean_iou: 0.4635 - val_accuracy: 0.3745 - val_loss: 2.9475 - val_mean_iou: 0.1187 - learning_rate: 0.0010
# Epoch 22/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.7483 - loss: 0.6636 - mean_iou: 0.4584 - val_accuracy: 0.3779 - val_loss: 3.0301 - val_mean_iou: 0.1244 - learning_rate: 0.0010
# Epoch 23/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.7455 - loss: 0.6711 - mean_iou: 0.4471 - val_accuracy: 0.6187 - val_loss: 1.2891 - val_mean_iou: 0.3173 - learning_rate: 0.0010
# Epoch 24/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7429 - loss: 0.6717 - mean_iou: 0.4497 - val_accuracy: 0.5812 - val_loss: 1.3721 - val_mean_iou: 0.2929 - learning_rate: 0.0010
# Epoch 25/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7504 - loss: 0.6456 - mean_iou: 0.4509 - val_accuracy: 0.6545 - val_loss: 1.2067 - val_mean_iou: 0.3467 - learning_rate: 0.0010
# Epoch 26/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7545 - loss: 0.6384 - mean_iou: 0.4571 - val_accuracy: 0.4032 - val_loss: 2.3280 - val_mean_iou: 0.1359 - learning_rate: 0.0010
# Epoch 27/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7580 - loss: 0.6381 - mean_iou: 0.4684 - val_accuracy: 0.5099 - val_loss: 1.5028 - val_mean_iou: 0.2087 - learning_rate: 0.0010
# Epoch 28/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7635 - loss: 0.6274 - mean_iou: 0.4719 - val_accuracy: 0.4215 - val_loss: 1.8828 - val_mean_iou: 0.1465 - learning_rate: 0.0010
# Epoch 29/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7698 - loss: 0.6149 - mean_iou: 0.4704 - val_accuracy: 0.5292 - val_loss: 1.9870 - val_mean_iou: 0.2092 - learning_rate: 0.0010
# Epoch 30/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7638 - loss: 0.6246 - mean_iou: 0.4633 - val_accuracy: 0.2729 - val_loss: 4.1831 - val_mean_iou: 0.0274 - learning_rate: 0.0010
# Epoch 31/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7661 - loss: 0.6167 - mean_iou: 0.4740 - val_accuracy: 0.5252 - val_loss: 1.5687 - val_mean_iou: 0.2242 - learning_rate: 0.0010
# Epoch 32/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7795 - loss: 0.5872 - mean_iou: 0.4767 - val_accuracy: 0.5055 - val_loss: 1.8536 - val_mean_iou: 0.2351 - learning_rate: 0.0010
# Epoch 33/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7797 - loss: 0.5804 - mean_iou: 0.4790 - val_accuracy: 0.3030 - val_loss: 4.6792 - val_mean_iou: 0.0542 - learning_rate: 0.0010
# Epoch 34/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7771 - loss: 0.5827 - mean_iou: 0.4794 - val_accuracy: 0.5915 - val_loss: 1.5050 - val_mean_iou: 0.2816 - learning_rate: 0.0010
# Epoch 35/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7735 - loss: 0.5953 - mean_iou: 0.4756 - val_accuracy: 0.3318 - val_loss: 4.6437 - val_mean_iou: 0.0665 - learning_rate: 0.0010
# Epoch 36/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7741 - loss: 0.5904 - mean_iou: 0.4765 - val_accuracy: 0.5691 - val_loss: 1.6367 - val_mean_iou: 0.2652 - learning_rate: 0.0010
# Epoch 37/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7812 - loss: 0.5726 - mean_iou: 0.4870 - val_accuracy: 0.4114 - val_loss: 2.7585 - val_mean_iou: 0.1254 - learning_rate: 0.0010
# Epoch 38/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7896 - loss: 0.5555 - mean_iou: 0.4901 - val_accuracy: 0.5631 - val_loss: 1.7690 - val_mean_iou: 0.2398 - learning_rate: 0.0010
# Epoch 39/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7834 - loss: 0.5648 - mean_iou: 0.4794 - val_accuracy: 0.5575 - val_loss: 1.5580 - val_mean_iou: 0.2672 - learning_rate: 0.0010
# Epoch 40/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7805 - loss: 0.5716 - mean_iou: 0.4794 - val_accuracy: 0.6678 - val_loss: 1.0015 - val_mean_iou: 0.3605 - learning_rate: 0.0010
# Epoch 41/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7839 - loss: 0.5675 - mean_iou: 0.4901 - val_accuracy: 0.5472 - val_loss: 1.5690 - val_mean_iou: 0.2542 - learning_rate: 0.0010
# Epoch 42/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7893 - loss: 0.5551 - mean_iou: 0.4887 - val_accuracy: 0.6192 - val_loss: 1.4819 - val_mean_iou: 0.3229 - learning_rate: 0.0010
# Epoch 43/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8031 - loss: 0.5193 - mean_iou: 0.4993 - val_accuracy: 0.6184 - val_loss: 1.2198 - val_mean_iou: 0.3229 - learning_rate: 0.0010
# Epoch 44/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7794 - loss: 0.5813 - mean_iou: 0.4738 - val_accuracy: 0.6151 - val_loss: 1.3914 - val_mean_iou: 0.3234 - learning_rate: 0.0010
# Epoch 45/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7861 - loss: 0.5591 - mean_iou: 0.4927 - val_accuracy: 0.4432 - val_loss: 2.7816 - val_mean_iou: 0.1507 - learning_rate: 0.0010
# Epoch 46/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8031 - loss: 0.5204 - mean_iou: 0.4963 - val_accuracy: 0.5337 - val_loss: 1.7959 - val_mean_iou: 0.2447 - learning_rate: 0.0010
# Epoch 47/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.8018 - loss: 0.5144 - mean_iou: 0.5055 - val_accuracy: 0.7004 - val_loss: 1.0394 - val_mean_iou: 0.3955 - learning_rate: 0.0010
# Epoch 48/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8055 - loss: 0.5096 - mean_iou: 0.4995 - val_accuracy: 0.5830 - val_loss: 1.6178 - val_mean_iou: 0.2720 - learning_rate: 0.0010
# Epoch 49/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8170 - loss: 0.4845 - mean_iou: 0.5120 - val_accuracy: 0.5027 - val_loss: 2.3351 - val_mean_iou: 0.2004 - learning_rate: 0.0010
# Epoch 50/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8154 - loss: 0.4803 - mean_iou: 0.5102 - val_accuracy: 0.6799 - val_loss: 1.0227 - val_mean_iou: 0.3578 - learning_rate: 0.0010
# Epoch 51/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8149 - loss: 0.4825 - mean_iou: 0.5057 - val_accuracy: 0.6789 - val_loss: 1.0993 - val_mean_iou: 0.3571 - learning_rate: 0.0010
# Epoch 52/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8085 - loss: 0.4977 - mean_iou: 0.5028 - val_accuracy: 0.4027 - val_loss: 3.3256 - val_mean_iou: 0.1169 - learning_rate: 0.0010
# Epoch 53/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8160 - loss: 0.4838 - mean_iou: 0.5042 - val_accuracy: 0.6575 - val_loss: 1.1696 - val_mean_iou: 0.3333 - learning_rate: 0.0010
# Epoch 54/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8274 - loss: 0.4573 - mean_iou: 0.5097 - val_accuracy: 0.6822 - val_loss: 1.0811 - val_mean_iou: 0.3644 - learning_rate: 0.0010
# Epoch 55/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8342 - loss: 0.4434 - mean_iou: 0.5178 - val_accuracy: 0.4977 - val_loss: 2.1991 - val_mean_iou: 0.2004 - learning_rate: 0.0010
# Epoch 56/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.8317 - loss: 0.4439 - mean_iou: 0.5198 - val_accuracy: 0.6634 - val_loss: 1.1463 - val_mean_iou: 0.3488 - learning_rate: 1.0000e-04
# Epoch 57/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8582 - loss: 0.3794 - mean_iou: 0.5403 - val_accuracy: 0.7384 - val_loss: 0.7980 - val_mean_iou: 0.4221 - learning_rate: 1.0000e-04
# Epoch 58/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8597 - loss: 0.3707 - mean_iou: 0.5399 - val_accuracy: 0.7640 - val_loss: 0.6685 - val_mean_iou: 0.4545 - learning_rate: 1.0000e-04
# Epoch 59/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8659 - loss: 0.3624 - mean_iou: 0.5387 - val_accuracy: 0.7707 - val_loss: 0.6464 - val_mean_iou: 0.4589 - learning_rate: 1.0000e-04
# Epoch 60/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8617 - loss: 0.3679 - mean_iou: 0.5362 - val_accuracy: 0.7738 - val_loss: 0.6360 - val_mean_iou: 0.4643 - learning_rate: 1.0000e-04
# Epoch 61/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8637 - loss: 0.3613 - mean_iou: 0.5365 - val_accuracy: 0.7745 - val_loss: 0.6339 - val_mean_iou: 0.4618 - learning_rate: 1.0000e-04
# Epoch 62/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8671 - loss: 0.3609 - mean_iou: 0.5349 - val_accuracy: 0.7745 - val_loss: 0.6272 - val_mean_iou: 0.4621 - learning_rate: 1.0000e-04
# Epoch 63/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8696 - loss: 0.3547 - mean_iou: 0.5407 - val_accuracy: 0.7716 - val_loss: 0.6482 - val_mean_iou: 0.4625 - learning_rate: 1.0000e-04
# Epoch 64/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8765 - loss: 0.3326 - mean_iou: 0.5497 - val_accuracy: 0.7722 - val_loss: 0.6551 - val_mean_iou: 0.4646 - learning_rate: 1.0000e-04
# Epoch 65/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8712 - loss: 0.3438 - mean_iou: 0.5383 - val_accuracy: 0.7789 - val_loss: 0.6490 - val_mean_iou: 0.4710 - learning_rate: 1.0000e-04
# Epoch 66/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8756 - loss: 0.3354 - mean_iou: 0.5439 - val_accuracy: 0.7698 - val_loss: 0.6623 - val_mean_iou: 0.4585 - learning_rate: 1.0000e-04
# Epoch 67/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8660 - loss: 0.3536 - mean_iou: 0.5355 - val_accuracy: 0.7773 - val_loss: 0.6441 - val_mean_iou: 0.4688 - learning_rate: 1.0000e-04
# Epoch 68/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8772 - loss: 0.3281 - mean_iou: 0.5439 - val_accuracy: 0.7735 - val_loss: 0.6543 - val_mean_iou: 0.4629 - learning_rate: 1.0000e-04
# Epoch 69/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8783 - loss: 0.3277 - mean_iou: 0.5457 - val_accuracy: 0.7749 - val_loss: 0.6569 - val_mean_iou: 0.4655 - learning_rate: 1.0000e-04
# Epoch 70/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8810 - loss: 0.3197 - mean_iou: 0.5436 - val_accuracy: 0.7749 - val_loss: 0.6523 - val_mean_iou: 0.4649 - learning_rate: 1.0000e-04
# Epoch 71/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8783 - loss: 0.3264 - mean_iou: 0.5499 - val_accuracy: 0.7791 - val_loss: 0.6554 - val_mean_iou: 0.4699 - learning_rate: 1.0000e-04
# Epoch 72/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8823 - loss: 0.3161 - mean_iou: 0.5503 - val_accuracy: 0.7747 - val_loss: 0.6655 - val_mean_iou: 0.4660 - learning_rate: 1.0000e-04
# Epoch 73/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8818 - loss: 0.3193 - mean_iou: 0.5438 - val_accuracy: 0.7768 - val_loss: 0.6700 - val_mean_iou: 0.4639 - learning_rate: 1.0000e-04
# Epoch 74/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8828 - loss: 0.3129 - mean_iou: 0.5457 - val_accuracy: 0.7779 - val_loss: 0.6592 - val_mean_iou: 0.4671 - learning_rate: 1.0000e-04
# Epoch 75/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8842 - loss: 0.3122 - mean_iou: 0.5482 - val_accuracy: 0.7769 - val_loss: 0.6653 - val_mean_iou: 0.4675 - learning_rate: 1.0000e-04
# Epoch 76/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8843 - loss: 0.3118 - mean_iou: 0.5475 - val_accuracy: 0.7732 - val_loss: 0.6708 - val_mean_iou: 0.4649 - learning_rate: 1.0000e-04
# Epoch 77/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8853 - loss: 0.3053 - mean_iou: 0.5456 - val_accuracy: 0.7763 - val_loss: 0.6682 - val_mean_iou: 0.4687 - learning_rate: 1.0000e-04
# Epoch 78/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8863 - loss: 0.3021 - mean_iou: 0.5510 - val_accuracy: 0.7748 - val_loss: 0.6666 - val_mean_iou: 0.4680 - learning_rate: 1.0000e-05
# Epoch 79/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8898 - loss: 0.2977 - mean_iou: 0.5524 - val_accuracy: 0.7727 - val_loss: 0.6676 - val_mean_iou: 0.4659 - learning_rate: 1.0000e-05
# Epoch 80/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8872 - loss: 0.3001 - mean_iou: 0.5487 - val_accuracy: 0.7723 - val_loss: 0.6689 - val_mean_iou: 0.4645 - learning_rate: 1.0000e-05
# Epoch 81/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8942 - loss: 0.2861 - mean_iou: 0.5548 - val_accuracy: 0.7715 - val_loss: 0.6710 - val_mean_iou: 0.4645 - learning_rate: 1.0000e-05
# Epoch 82/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8876 - loss: 0.3018 - mean_iou: 0.5504 - val_accuracy: 0.7717 - val_loss: 0.6716 - val_mean_iou: 0.4646 - learning_rate: 1.0000e-05
# Epoch 83/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8895 - loss: 0.2976 - mean_iou: 0.5513 - val_accuracy: 0.7720 - val_loss: 0.6716 - val_mean_iou: 0.4650 - learning_rate: 1.0000e-05
# Epoch 84/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8947 - loss: 0.2893 - mean_iou: 0.5538 - val_accuracy: 0.7721 - val_loss: 0.6725 - val_mean_iou: 0.4648 - learning_rate: 1.0000e-05
# Epoch 85/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8907 - loss: 0.2940 - mean_iou: 0.5485 - val_accuracy: 0.7714 - val_loss: 0.6739 - val_mean_iou: 0.4640 - learning_rate: 1.0000e-05
# Epoch 86/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8927 - loss: 0.2879 - mean_iou: 0.5523 - val_accuracy: 0.7705 - val_loss: 0.6733 - val_mean_iou: 0.4637 - learning_rate: 1.0000e-05
# Epoch 87/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8911 - loss: 0.2970 - mean_iou: 0.5515 - val_accuracy: 0.7707 - val_loss: 0.6734 - val_mean_iou: 0.4639 - learning_rate: 1.0000e-05
# Epoch 88/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8940 - loss: 0.2868 - mean_iou: 0.5540 - val_accuracy: 0.7712 - val_loss: 0.6737 - val_mean_iou: 0.4639 - learning_rate: 1.0000e-05
# Epoch 89/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8957 - loss: 0.2855 - mean_iou: 0.5555 - val_accuracy: 0.7714 - val_loss: 0.6751 - val_mean_iou: 0.4634 - learning_rate: 1.0000e-05
# Epoch 90/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8910 - loss: 0.2918 - mean_iou: 0.5487 - val_accuracy: 0.7709 - val_loss: 0.6755 - val_mean_iou: 0.4626 - learning_rate: 1.0000e-05
# Epoch 91/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8930 - loss: 0.2904 - mean_iou: 0.5527 - val_accuracy: 0.7705 - val_loss: 0.6768 - val_mean_iou: 0.4624 - learning_rate: 1.0000e-05
# Epoch 92/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8879 - loss: 0.3063 - mean_iou: 0.5406 - val_accuracy: 0.7705 - val_loss: 0.6760 - val_mean_iou: 0.4632 - learning_rate: 1.0000e-05
# Epoch 93/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8899 - loss: 0.3024 - mean_iou: 0.5501 - val_accuracy: 0.7703 - val_loss: 0.6771 - val_mean_iou: 0.4628 - learning_rate: 1.0000e-06
# Epoch 94/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8919 - loss: 0.2936 - mean_iou: 0.5472 - val_accuracy: 0.7702 - val_loss: 0.6770 - val_mean_iou: 0.4626 - learning_rate: 1.0000e-06
# Epoch 95/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8932 - loss: 0.2904 - mean_iou: 0.5541 - val_accuracy: 0.7701 - val_loss: 0.6777 - val_mean_iou: 0.4623 - learning_rate: 1.0000e-06
# Epoch 96/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8946 - loss: 0.2866 - mean_iou: 0.5538 - val_accuracy: 0.7698 - val_loss: 0.6785 - val_mean_iou: 0.4617 - learning_rate: 1.0000e-06
# Epoch 97/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8958 - loss: 0.2862 - mean_iou: 0.5576 - val_accuracy: 0.7698 - val_loss: 0.6785 - val_mean_iou: 0.4618 - learning_rate: 1.0000e-06
# Epoch 98/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8952 - loss: 0.2865 - mean_iou: 0.5520 - val_accuracy: 0.7698 - val_loss: 0.6785 - val_mean_iou: 0.4617 - learning_rate: 1.0000e-06
# Epoch 99/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8973 - loss: 0.2801 - mean_iou: 0.5564 - val_accuracy: 0.7697 - val_loss: 0.6785 - val_mean_iou: 0.4617 - learning_rate: 1.0000e-06
# Epoch 100/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8928 - loss: 0.2928 - mean_iou: 0.5523 - val_accuracy: 0.7696 - val_loss: 0.6790 - val_mean_iou: 0.4616 - learning_rate: 1.0000e-06
# Epoch 101/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8945 - loss: 0.2893 - mean_iou: 0.5493 - val_accuracy: 0.7697 - val_loss: 0.6792 - val_mean_iou: 0.4617 - learning_rate: 1.0000e-06
# Final validation Mean Intersection Over Union: 47.1%
# Model saved to model_241202_110358.keras

# %%
# Plot and display training and validation loss
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Cross Entropy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation accuracy
plt.figure(figsize=(18, 3))
plt.plot(history['accuracy'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_accuracy'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation mean IoU
plt.figure(figsize=(18, 3))
plt.plot(history['mean_iou'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_mean_iou'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Mean Intersection over Union')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## 🔮 Predictions on the Test Set

# %%
# If model_filename is not defined, load the most recent model from Google Drive
if "model_filename" not in globals() or model_filename is None:
    files = [f for f in os.listdir('.') if os.path.isfile(f) and f.startswith('model_') and f.endswith('.keras')]
    files.sort(key=lambda x: os.path.getmtime(x), reverse=True)
    if files:
        model_filename = files[0]
    else:
        raise FileNotFoundError("No model files found in the current directory.")

# %%
model = tfk.models.load_model(model_filename, compile=False)
print(f"Model loaded from {model_filename}")
# Out:
# Model loaded from model_241202_110358.keras

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=-1)
print(f"Predictions shape: {preds.shape}")
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step
# Predictions shape: (10022, 64, 128)

# %%
# Plot some predictions 
num_samples = 8
# Only take the first `num_samples` from X_test and preds
images = X_test[:num_samples]
predictions = preds[:num_samples]

# Adjust the number of classes to match the actual classes in the predictions (excluding 0)
num_classes = len(classes) # Excluding background

# Create colormap based on the number of classes
colormap = create_segmentation_colormap(num_classes)

# Create a list to store the handles for the legend (only once)
handles = []

for i in range(num_samples):
    # Get the i-th image and its prediction
    image = images[i]
    predicted_mask = predictions[i]

    # Create figure with subplots
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Plot original image
    axes[0].set_title("Original Image")
    axes[0].imshow(image, cmap='gray')
    axes[0].axis('off')

    # Plot predicted mask
    axes[1].set_title("Predicted Mask")
    colored_pred = apply_colormap(predicted_mask, colormap)
    axes[1].imshow(colored_pred)
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()
    plt.close()

# After all images have been plotted, add the legend once
# We collect handles for the legend here, only once
for label_idx in category_map: 
    color = colormap[label_idx]  # Use array indexing, subtracting 1 to account for class 0 exclusion
    handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=classes[label_idx]))

# Create a single legend displayed at the bottom
fig, ax = plt.subplots(figsize=(10, 2))  # Make the figure wide enough for a horizontal legend
ax.legend(handles=handles, loc='center', bbox_to_anchor=(0.5, 0), title="Classes", ncol=len(category_map))
ax.axis('off')
plt.show()

# %% [markdown]
# ## 📊 Prepare the Submission

# %%
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)
